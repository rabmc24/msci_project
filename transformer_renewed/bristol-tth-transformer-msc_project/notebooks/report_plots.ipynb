# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# ...existing code...
import pandas as pd

# Define file paths
dileptonic_path = '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/TTTo2L2Nu.parquet'
semileptonic_path = '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/TTToSemiLeptonic.parquet'
hadronic_path = '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/TTToHadronic.parquet'
ttH_path = '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ttH_HToInvisible_M125.parquet'

zjets_individual = [
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-100To200.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-200To400.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-400To600.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-600To800.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-800To1200.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-1200To2500.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-2500ToInf.parquet',
]

wjets_individual = [
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-100To200.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-200To400.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-400To600.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-600To800.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-800To1200.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-1200To2500.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-2500ToInf.parquet',
]

# Load DataFrames
dileptonic = pd.read_parquet(dileptonic_path)
semileptonic = pd.read_parquet(semileptonic_path)
hadronic = pd.read_parquet(hadronic_path)
ttH = pd.read_parquet(ttH_path)

# Filter DataFrames
dileptonic = dileptonic[(dileptonic['region'] == 0) | (dileptonic['region'] == 6)]
semileptonic = semileptonic[(semileptonic['region'] == 0) | (semileptonic['region'] == 6)]
hadronic = hadronic[(hadronic['region'] == 0) | (hadronic['region'] == 6)]
ttH = ttH[(ttH['region'] == 0) | (ttH['region'] == 6)]

# Load and concatenate Z+Jets DataFrames
z_jets_dfs = [pd.read_parquet(file) for file in zjets_individual]
z_jets = pd.concat(z_jets_dfs, ignore_index=True)
z_jets = z_jets[(z_jets['region'] == 0) | (z_jets['region'] == 6)]

# Load and concatenate W+Jets DataFrames
w_jets_dfs = [pd.read_parquet(file) for file in wjets_individual]
w_jets = pd.concat(w_jets_dfs, ignore_index=True)
w_jets = w_jets[(w_jets['region'] == 0) | (w_jets['region'] == 6)]

# Print shapes of filtered DataFrames
print(f"Shape of dileptonic DataFrame: {dileptonic.shape}")
print(f"Shape of semileptonic DataFrame: {semileptonic.shape}")
print(f"Shape of hadronic DataFrame: {hadronic.shape}")
print(f"Shape of ttH DataFrame: {ttH.shape}")
print(f"Shape of Z+Jets DataFrame: {z_jets.shape}")
print(f"Shape of W+Jets DataFrame: {w_jets.shape}")
# ...existing code...
# Out:
# Shape of dileptonic DataFrame: (174473, 49)
# Shape of semileptonic DataFrame: (1297663, 49)
# Shape of hadronic DataFrame: (18153, 49)
# Shape of ttH DataFrame: (240373, 49)
# Shape of Z+Jets DataFrame: (140986, 49)
# Shape of W+Jets DataFrame: (149849, 49)

# %%
data = {
    'DataFrame': ['dileptonic', 'semileptonic', 'hadronic', 'ttH', 'z_jets', 'w_jets'],
    'Length': [len(dileptonic), len(semileptonic), len(hadronic), len(ttH), len(z_jets), len(w_jets)],
}

df = pd.DataFrame(data)

# Plot bar chart
plt.figure(figsize=(10, 6))
plt.bar(df['DataFrame'], df['Length'], color='skyblue')
plt.xlabel('DataFrame')
plt.ylabel('Length')
plt.yscale('log')
plt.title('Length of Each DataFrame')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()




plt.figure(figsize=(10, 6))
plt.bar(df['DataFrame'], df['Length'], color='skyblue')
plt.xlabel('DataFrame')
plt.ylabel('Length')
plt.title('Length of Each DataFrame')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# ...existing code...
import pandas as pd
import matplotlib.pyplot as plt

# Define file paths
dileptonic_path = '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/TTTo2L2Nu.parquet'
semileptonic_path = '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/TTToSemiLeptonic.parquet'
hadronic_path = '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/TTToHadronic.parquet'
ttH_path = '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ttH_HToInvisible_M125.parquet'

zjets_individual = [
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-100To200.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-200To400.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-400To600.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-600To800.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-800To1200.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-1200To2500.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-2500ToInf.parquet',
]

wjets_individual = [
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-100To200.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-200To400.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-400To600.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-600To800.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-800To1200.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-1200To2500.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-2500ToInf.parquet',
]

# Define target luminosity (in fb^-1)
target_luminosity = 200000  # Example value for Run 2

# Load DataFrames
dileptonic = pd.read_parquet(dileptonic_path)
semileptonic = pd.read_parquet(semileptonic_path)
hadronic = pd.read_parquet(hadronic_path)
ttH = pd.read_parquet(ttH_path)

# Filter DataFrames
dileptonic = dileptonic[(dileptonic['region'] == 0) | (dileptonic['region'] == 6)]
semileptonic = semileptonic[(semileptonic['region'] == 0) | (semileptonic['region'] == 6)]
hadronic = hadronic[(hadronic['region'] == 0) | (hadronic['region'] == 6)]
ttH = ttH[(ttH['region'] == 0) | (ttH['region'] == 6)]

# Load and concatenate Z+Jets DataFrames
z_jets_dfs = [pd.read_parquet(file) for file in zjets_individual]
z_jets = pd.concat(z_jets_dfs, ignore_index=True)
z_jets = z_jets[(z_jets['region'] == 0) | (z_jets['region'] == 6)]

# Load and concatenate W+Jets DataFrames
w_jets_dfs = [pd.read_parquet(file) for file in wjets_individual]
w_jets = pd.concat(w_jets_dfs, ignore_index=True)
w_jets = w_jets[(w_jets['region'] == 0) | (w_jets['region'] == 6)]

# Scale weights to target luminosity
def scale_weights(df, target_luminosity):
    # Assuming the weight is normalized to 1 fb^-1
    df['weight_scaled'] = df['weight_nominal'] * target_luminosity
    return df

dileptonic = scale_weights(dileptonic, target_luminosity)
semileptonic = scale_weights(semileptonic, target_luminosity)
hadronic = scale_weights(hadronic, target_luminosity)
ttH = scale_weights(ttH, target_luminosity)
z_jets = scale_weights(z_jets, target_luminosity)
w_jets = scale_weights(w_jets, target_luminosity)

# Calculate sum of scaled weights for each DataFrame
sum_dileptonic = dileptonic['weight_scaled'].sum()
sum_semileptonic = semileptonic['weight_scaled'].sum()
sum_hadronic = hadronic['weight_scaled'].sum()
sum_ttH = ttH['weight_scaled'].sum()
sum_z_jets = z_jets['weight_scaled'].sum()
sum_w_jets = w_jets['weight_scaled'].sum()

# Store lengths of DataFrames
data = {
    'DataFrame': ['ttH_HToInvisible','dileptonic', 'semileptonic', 'hadronic', 'z_jets', 'w_jets'],
    'Sum_Scaled_Weights': [sum_ttH, sum_dileptonic, sum_semileptonic, sum_hadronic, sum_z_jets, sum_w_jets]
}

df = pd.DataFrame(data)

# Plot bar chart
plt.figure(figsize=(10, 6))
plt.bar(df['DataFrame'], df['Sum_Scaled_Weights'], color='skyblue')
plt.xlabel('DataFrame')
plt.ylabel('Sum of Scaled Weights')
plt.title('Sum of Scaled Weights for Each DataFrame')
#plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# ...existing code...

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['DataFrame'], df['Sum_Scaled_Weights'], color='skyblue')
plt.xlabel('Channel')
plt.ylabel('Number of events (weighted)')
plt.yscale('log')
plt.tight_layout()
plt.show()
# ...existing code...

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['DataFrame'], df['Sum_Scaled_Weights']*200000, color='skyblue')
plt.xlabel('Channel')
plt.ylabel('Number of events (weighted)')
#plt.yscale('log')
plt.tight_layout()
plt.show()
# ...existing code...

# %%
# ...existing code...
plt.figure(figsize=(10, 6))
plt.barh(df['DataFrame'], df['Sum_Scaled_Weights'], color='skyblue')
plt.ylabel('DataFrame')
plt.xlabel('Sum of Scaled Weights')
plt.title('Sum of Scaled Weights for Each DataFrame')
plt.tight_layout()
plt.show()
# ...existing code...

# %%
# ...existing code...
import pandas as pd
import matplotlib.pyplot as plt

# Define file paths
dileptonic_path = '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/TTTo2L2Nu.parquet'
semileptonic_path = '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/TTToSemiLeptonic.parquet'
hadronic_path = '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/TTToHadronic.parquet'
ttH_path = '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ttH_HToInvisible_M125.parquet'

zjets_individual = [
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-100To200.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-200To400.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-400To600.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-600To800.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-800To1200.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-1200To2500.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-2500ToInf.parquet',
]

wjets_individual = [
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-100To200.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-200To400.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-400To600.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-600To800.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-800To1200.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-1200To2500.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-2500ToInf.parquet',
]

# Define target luminosity (in fb^-1)
target_luminosity = 200000  # Example value for Run 2

# Load DataFrames
dileptonic = pd.read_parquet(dileptonic_path)
semileptonic = pd.read_parquet(semileptonic_path)
hadronic = pd.read_parquet(hadronic_path)
ttH = pd.read_parquet(ttH_path)

# Filter DataFrames
dileptonic = dileptonic[(dileptonic['region'] == 0) | (dileptonic['region'] == 6)]
semileptonic = semileptonic[(semileptonic['region'] == 0) | (semileptonic['region'] == 6)]
hadronic = hadronic[(hadronic['region'] == 0) | (hadronic['region'] == 6)]
ttH = ttH[(ttH['region'] == 0) | (ttH['region'] == 6)]

# Load and concatenate Z+Jets DataFrames
z_jets_dfs = [pd.read_parquet(file) for file in zjets_individual]
z_jets = pd.concat(z_jets_dfs, ignore_index=True)
z_jets = z_jets[(z_jets['region'] == 0) | (z_jets['region'] == 6)]

# Load and concatenate W+Jets DataFrames
w_jets_dfs = [pd.read_parquet(file) for file in wjets_individual]
w_jets = pd.concat(w_jets_dfs, ignore_index=True)
w_jets = w_jets[(w_jets['region'] == 0) | (w_jets['region'] == 6)]

# Scale weights to target luminosity
def scale_weights(df, target_luminosity):
    # Assuming the weight is normalized to 1 fb^-1
    df['weight_scaled'] = df['weight_nominal'] * target_luminosity
    return df

dileptonic = scale_weights(dileptonic, target_luminosity)
semileptonic = scale_weights(semileptonic, target_luminosity)
hadronic = scale_weights(hadronic, target_luminosity)
ttH = scale_weights(ttH, target_luminosity)
z_jets = scale_weights(z_jets, target_luminosity)
w_jets = scale_weights(w_jets, target_luminosity)

# Calculate sum of scaled weights for each DataFrame
sum_dileptonic = dileptonic['weight_scaled'].sum()
sum_semileptonic = semileptonic['weight_scaled'].sum()
sum_hadronic = hadronic['weight_scaled'].sum()
sum_ttH = ttH['weight_scaled'].sum()
sum_z_jets = z_jets['weight_scaled'].sum()
sum_w_jets = w_jets['weight_scaled'].sum()

# Store lengths of DataFrames
data = {
    'DataFrame': ['dileptonic', 'semileptonic', 'hadronic', 'ttH', 'z_jets', 'w_jets'],
    'Sum_Scaled_Weights': [sum_dileptonic, sum_semileptonic, sum_hadronic, sum_ttH, sum_z_jets, sum_w_jets]
}

df = pd.DataFrame(data)

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(df['Sum_Scaled_Weights'], labels=df['DataFrame'], autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Sum of Scaled Weights')
plt.tight_layout()
plt.show()
# ...existing code...

# %%
plt.figure(figsize=(8, 8))
plt.pie(df['Sum_Scaled_Weights'], labels=df['DataFrame'], autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Sum of Scaled Weights')
plt.tight_layout()
plt.show()

# %%
# ...existing code...
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define file paths
dileptonic_path = '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/TTTo2L2Nu.parquet'
semileptonic_path = '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/TTToSemiLeptonic.parquet'
hadronic_path = '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/TTToHadronic.parquet'
ttH_path = '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ttH_HToInvisible_M125.parquet'

zjets_individual = [
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-100To200.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-200To400.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-400To600.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-600To800.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-800To1200.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-1200To2500.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/ZJetsToNuNu_HT-2500ToInf.parquet',
]

wjets_individual = [
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-100To200.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-200To400.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-400To600.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-600To800.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-800To1200.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-1200To2500.parquet',
    '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/WJetsToLNu_HT-2500ToInf.parquet',
]

# Define target luminosity (in fb^-1)
target_luminosity = 137  # Example value for Run 2

# Load DataFrames
dileptonic = pd.read_parquet(dileptonic_path)
semileptonic = pd.read_parquet(semileptonic_path)
hadronic = pd.read_parquet(hadronic_path)
ttH = pd.read_parquet(ttH_path)

# Filter DataFrames
dileptonic = dileptonic[(dileptonic['region'] == 0) | (dileptonic['region'] == 6)]
semileptonic = semileptonic[(semileptonic['region'] == 0) | (semileptonic['region'] == 6)]
hadronic = hadronic[(hadronic['region'] == 0) | (hadronic['region'] == 6)]
ttH = ttH[(ttH['region'] == 0) | (ttH['region'] == 6)]

# Load and concatenate Z+Jets DataFrames
z_jets_dfs = [pd.read_parquet(file) for file in zjets_individual]
z_jets = pd.concat(z_jets_dfs, ignore_index=True)
z_jets = z_jets[(z_jets['region'] == 0) | (z_jets['region'] == 6)]

# Load and concatenate W+Jets DataFrames
w_jets_dfs = [pd.read_parquet(file) for file in wjets_individual]
w_jets = pd.concat(w_jets_dfs, ignore_index=True)
w_jets = w_jets[(w_jets['region'] == 0) | (w_jets['region'] == 6)]

# Scale weights to target luminosity
def scale_weights(df, target_luminosity):
    # Assuming the weight is normalized to 1 fb^-1
    df['weight_scaled'] = df['weight_nominal'] * target_luminosity
    return df

dileptonic = scale_weights(dileptonic, target_luminosity)
semileptonic = scale_weights(semileptonic, target_luminosity)
hadronic = scale_weights(hadronic, target_luminosity)
ttH = scale_weights(ttH, target_luminosity)
z_jets = scale_weights(z_jets, target_luminosity)
w_jets = scale_weights(w_jets, target_luminosity)

# Calculate sum of scaled weights for each DataFrame
sum_dileptonic = dileptonic['weight_scaled'].sum()
sum_semileptonic = semileptonic['weight_scaled'].sum()
sum_hadronic = hadronic['weight_scaled'].sum()
sum_ttH = ttH['weight_scaled'].sum()
sum_z_jets = z_jets['weight_scaled'].sum()
sum_w_jets = w_jets['weight_scaled'].sum()

# Store lengths of DataFrames
data = {
    'DataFrame': ['dileptonic', 'semileptonic', 'hadronic', 'ttH', 'z_jets', 'w_jets'],
    'Sum_Scaled_Weights': [sum_dileptonic, sum_semileptonic, sum_hadronic, sum_ttH, sum_z_jets, sum_w_jets]
}

df = pd.DataFrame(data)

# Plot horizontal bar chart with adjusted bar width and spacing
plt.figure(figsize=(10, 6))
bar_width = 0.6  # Adjust bar width (default is 0.8)
y_pos = np.arange(len(df['DataFrame']))  # Get y positions for the bars

plt.barh(y_pos, df['Sum_Scaled_Weights'], height=bar_width, color='skyblue')  # Use bar_width for height
plt.yticks(y_pos, df['DataFrame'])  # Set y ticks to DataFrame names
plt.ylabel('DataFrame')
plt.xlabel('Sum of Scaled Weights')
plt.title('Sum of Scaled Weights for Each DataFrame')
plt.tight_layout()
plt.show()
# ...existing code...

# %%
# ...existing code...
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define file paths
base_path = '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/'

file_names = [
    'ttH_HToInvisible_M125',

    # ttbar events (1)
    'TTToSemiLeptonic',
    'TTTo2L2Nu',
    'TTToHadronic',

    # ZJetsToNuNu events (2)
    'ZJetsToNuNu_HT-100To200',
    'ZJetsToNuNu_HT-200To400',
    'ZJetsToNuNu_HT-400To600',
    'ZJetsToNuNu_HT-600To800',
    'ZJetsToNuNu_HT-800To1200',
    'ZJetsToNuNu_HT-1200To2500',
    'ZJetsToNuNu_HT-2500ToInf',

    # WJetsToLNu events (3)
    'WJetsToLNu_HT-100To200',
    'WJetsToLNu_HT-200To400',
    'WJetsToLNu_HT-400To600',
    'WJetsToLNu_HT-600To800',
    'WJetsToLNu_HT-800To1200',
    'WJetsToLNu_HT-1200To2500',
    'WJetsToLNu_HT-2500ToInf',

    # QCD events (4)
    'QCD_HT100to200',
    'QCD_HT200to300',
    'QCD_HT300to500',
    'QCD_HT500to700',
    'QCD_HT700to1000',
    'QCD_HT1000to1500',
    'QCD_HT1500to2000',
    'QCD_HT2000toInf',

    # Multiboson events (5)
    'WW',
    'ZZ',
    'WZ',
    'WWW_4F',
    'WWZ_4F',
    'WZZ',
    'ZZZ',

    # ttV events (6)
    'TTWJetsToLNu',
    'TTZToLLNuNu_M-10',

    # EWK events (7)
    'EWKWPlus2Jets_WToLNu_M-50',
    'EWKWMinus2Jets_WToLNu_M-50',
    'EWKZ2Jets_ZToNuNu_M-50',
    'EWKZ2Jets_ZToLL_M-50',
]

# Define target luminosity (in fb^-1)
target_luminosity = 137  # Example value for Run 2

# Load and process DataFrames
data = []
for file_name in file_names:
    file_path = base_path + file_name + '.parquet'
    try:
        df = pd.read_parquet(file_path)
        df = df[(df['region'] == 0) | (df['region'] == 6)]
        df['weight_scaled'] = df['weight_nominal'] * target_luminosity
        sum_scaled_weights = df['weight_scaled'].sum()
        data.append([file_name, sum_scaled_weights])
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        data.append([file_name, 0])  # Append 0 if file not found

# Create DataFrame for plotting
df = pd.DataFrame(data, columns=['DataFrame', 'Sum_Scaled_Weights'])

# Plot horizontal bar chart with adjusted bar width and spacing
plt.figure(figsize=(12, 10))  # Adjust figure size for more bars
bar_width = 0.7  # Adjust bar width (default is 0.8)
y_pos = np.arange(len(df['DataFrame']))  # Get y positions for the bars

plt.barh(y_pos, df['Sum_Scaled_Weights'], height=bar_width, color='skyblue')  # Use bar_width for height
plt.yticks(y_pos, df['DataFrame'])  # Set y ticks to DataFrame names
plt.ylabel('DataFrame')
plt.xlabel('Sum of Scaled Weights')
plt.title('Sum of Scaled Weights for Each DataFrame')
plt.tight_layout()
plt.show()
# ...existing code...

# %%
# ...existing code...
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define file paths
base_path = '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/'

file_names = [
    'ttH_HToInvisible_M125',

    # ttbar events (1)
    'TTToSemiLeptonic',
    'TTTo2L2Nu',
    'TTToHadronic',

    # V+jets events (2)
    'ZJetsToNuNu_HT-100To200',
    'ZJetsToNuNu_HT-200To400',
    'ZJetsToNuNu_HT-400To600',
    'ZJetsToNuNu_HT-600To800',
    'ZJetsToNuNu_HT-800To1200',
    'ZJetsToNuNu_HT-1200To2500',
    'ZJetsToNuNu_HT-2500ToInf',
    'WJetsToLNu_HT-100To200',
    'WJetsToLNu_HT-200To400',
    'WJetsToLNu_HT-400To600',
    'WJetsToLNu_HT-600To800',
    'WJetsToLNu_HT-800To1200',
    'WJetsToLNu_HT-1200To2500',
    'WJetsToLNu_HT-2500ToInf',

    # Other (3)
    'QCD_HT100to200',
    'QCD_HT200to300',
    'QCD_HT300to500',
    'QCD_HT500to700',
    'QCD_HT700to1000',
    'QCD_HT1000to1500',
    'QCD_HT1500to2000',
    'QCD_HT2000toInf',
    'WW',
    'ZZ',
    'WZ',
    'WWW_4F',
    'WWZ_4F',
    'WZZ',
    'ZZZ',
    'TTWJetsToLNu',
    'TTZToLLNuNu_M-10',
    'EWKWPlus2Jets_WToLNu_M-50',
    'EWKWMinus2Jets_WToLNu_M-50',
    'EWKZ2Jets_ZToNuNu_M-50',
    'EWKZ2Jets_ZToLL_M-50',
]

# Define target luminosity (in fb^-1)
target_luminosity = 200000  # Example value for Run 2

# Load and process DataFrames
data = []
for file_name in file_names:
    file_path = base_path + file_name + '.parquet'
    try:
        df = pd.read_parquet(file_path)
        df = df[(df['region'] == 0) | (df['region'] == 6)]
        df['weight_scaled'] = df['weight_nominal'] * target_luminosity
        sum_scaled_weights = df['weight_scaled'].sum()
        data.append([file_name, sum_scaled_weights])
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        data.append([file_name, 0])  # Append 0 if file not found

# Create DataFrame for plotting
df = pd.DataFrame(data, columns=['DataFrame', 'Sum_Scaled_Weights'])

# Plot horizontal bar chart with adjusted bar width and spacing
plt.figure(figsize=(12, 10))  # Adjust figure size for more bars
bar_width = 0.7  # Adjust bar width (default is 0.8)
y_pos = np.arange(len(df['DataFrame']))  # Get y positions for the bars

plt.barh(y_pos, df['Sum_Scaled_Weights'], height=bar_width, color='skyblue')  # Use bar_width for height
plt.yticks(y_pos, df['DataFrame'])  # Set y ticks to DataFrame names
plt.ylabel('DataFrame')
plt.xlabel('Sum of Scaled Weights')
plt.title('Sum of Scaled Weights for Each DataFrame')
plt.tight_layout()
plt.show()
# ...existing code...

# %%
# ...existing code...
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define file paths
base_path = '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/'

file_names = [
    # ttbar events (1)
    'TTToSemiLeptonic',
    'TTTo2L2Nu',
    'TTToHadronic',

    # V+jets events (2)
    'ZJetsToNuNu_HT-100To200',
    'ZJetsToNuNu_HT-200To400',
    'ZJetsToNuNu_HT-400To600',
    'ZJetsToNuNu_HT-600To800',
    'ZJetsToNuNu_HT-800To1200',
    'ZJetsToNuNu_HT-1200To2500',
    'ZJetsToNuNu_HT-2500ToInf',
    'WJetsToLNu_HT-100To200',
    'WJetsToLNu_HT-200To400',
    'WJetsToLNu_HT-400To600',
    'WJetsToLNu_HT-600To800',
    'WJetsToLNu_HT-800To1200',
    'WJetsToLNu_HT-1200To2500',
    'WJetsToLNu_HT-2500ToInf',

    # Other (3)
    'QCD_HT100to200',
    'QCD_HT200to300',
    'QCD_HT300to500',
    'QCD_HT500to700',
    'QCD_HT700to1000',
    'QCD_HT1000to1500',
    'QCD_HT1500to2000',
    'QCD_HT2000toInf',
    'WW',
    'ZZ',
    'WZ',
    'WWW_4F',
    'WWZ_4F',
    'WZZ',
    'ZZZ',
    'TTWJetsToLNu',
    'TTZToLLNuNu_M-10',
    'EWKWPlus2Jets_WToLNu_M-50',
    'EWKWMinus2Jets_WToLNu_M-50',
    'EWKZ2Jets_ZToNuNu_M-50',
    'EWKZ2Jets_ZToLL_M-50',
]

# Define target luminosity (in fb^-1)
target_luminosity = 200000  # Example value for Run 2

# Load and process DataFrames
data = []
for file_name in file_names:
    file_path = base_path + file_name + '.parquet'
    try:
        df = pd.read_parquet(file_path)
        df = df[(df['region'] == 0) | (df['region'] == 6)]
        df['weight_scaled'] = df['weight_nominal'] * target_luminosity
        sum_scaled_weights = df['weight_scaled'].sum()
        data.append([file_name, sum_scaled_weights])
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        data.append([file_name, 0])  # Append 0 if file not found

# Create DataFrame for plotting
df = pd.DataFrame(data, columns=['DataFrame', 'Sum_Scaled_Weights'])

# Plot pie chart
plt.figure(figsize=(10, 10))  # Adjust figure size for better visualization
plt.pie(df['Sum_Scaled_Weights'], labels=df['DataFrame'], autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Sum of Scaled Weights (Excluding ttH)')
plt.tight_layout()
plt.show()
# ...existing code...

# %%
# ...existing code...
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Define file paths
base_path = '/dice/projects/CMS/Hinv/ml_datasets_ul_241111/ml_inputs_UL2018/'

file_names = [
    # ttbar events (1)
    'TTToSemiLeptonic',
    'TTTo2L2Nu',
    'TTToHadronic',

    # V+jets events (2)
    'ZJetsToNuNu_HT-100To200',
    'ZJetsToNuNu_HT-200To400',
    'ZJetsToNuNu_HT-400To600',
    'ZJetsToNuNu_HT-600To800',
    'ZJetsToNuNu_HT-800To1200',
    'ZJetsToNuNu_HT-1200To2500',
    'ZJetsToNuNu_HT-2500ToInf',
    'WJetsToLNu_HT-100To200',
    'WJetsToLNu_HT-200To400',
    'WJetsToLNu_HT-400To600',
    'WJetsToLNu_HT-600To800',
    'WJetsToLNu_HT-800To1200',
    'WJetsToLNu_HT-1200To2500',
    'WJetsToLNu_HT-2500ToInf',

    # Other (3)
    'QCD_HT100to200',
    'QCD_HT200to300',
    'QCD_HT300to500',
    'QCD_HT500to700',
    'QCD_HT700to1000',
    'QCD_HT1000to1500',
    'QCD_HT1500to2000',
    'QCD_HT2000toInf',
    'WW',
    'ZZ',
    'WZ',
    'WWW_4F',
    'WWZ_4F',
    'WZZ',
    'ZZZ',
    'TTWJetsToLNu',
    'TTZToLLNuNu_M-10',
    'EWKWPlus2Jets_WToLNu_M-50',
    'EWKWMinus2Jets_WToLNu_M-50',
    'EWKZ2Jets_ZToNuNu_M-50',
    'EWKZ2Jets_ZToLL_M-50',
]

# Define target luminosity (in fb^-1)
target_luminosity = 200000  # Example value for Run 2

# Load and process DataFrames
ttbar_weights = 0
vjets_weights = 0
other_weights = 0

for file_name in file_names:
    file_path = base_path + file_name + '.parquet'
    try:
        df = pd.read_parquet(file_path)
        df = df[(df['region'] == 0) | (df['region'] == 6)]
        df['weight_scaled'] = df['weight_nominal'] * target_luminosity
        sum_scaled_weights = df['weight_scaled'].sum()

        if file_name in ['TTToSemiLeptonic', 'TTTo2L2Nu', 'TTToHadronic']:
            ttbar_weights += sum_scaled_weights
        elif 'JetsToNuNu' in file_name or 'JetsToLNu' in file_name:
            vjets_weights += sum_scaled_weights
        else:
            other_weights += sum_scaled_weights

    except FileNotFoundError:
        print(f"File not found: {file_path}")

# Pie chart data
labels = ['ttbar', 'V+jets', 'Other']
sizes = [ttbar_weights, vjets_weights, other_weights]
colors = ['red', 'green', 'blue']

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Sum of Scaled Weights')
plt.tight_layout()
plt.show()
# ...existing code...

# %%
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Sum of Scaled Weights')
plt.tight_layout()
plt.show()
